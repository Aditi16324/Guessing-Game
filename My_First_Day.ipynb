# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi16324/Guessing-Game/blob/main/My_First_Day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Different Types Of Data

# %% [markdown]
# INT- whole(+ve)

# %% [markdown]
# CTRL + enter- same line

# %%
#variable - something which can change
population = 9873941174

print(population)
# Out:
# 9873941174

# %%
employment_rate = 23

print(employment_rate)
# Out:
# 23

# %%
years_until_2030 = 2030 - 2025

print(years_until_2030)
# Out:
# 5

# %%
inflation_rate = 5.34
gdp_growth = 6.3
price_of_wheat = 20.75

print(inflation_rate, gdp_growth, price_of_wheat)
# Out:
# 5.34 6.3 20.75

# %%
COUNTRY = "india"

economic_term = "inflation"

print(COUNTRY)
print(economic_term)
# Out:
# india
# inflation
